# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from nltk.corpus import stopwords

# %matplotlib inline

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
col_names = ['questions', 'a', 'b']
data_df = pd.read_csv("https://raw.githubusercontent.com/VIthulan/travel-text-classification/master/data/5000TravelQuestionsDataset.csv", error_bad_lines=False,header=None, names=col_names, encoding='latin-1')

# %%
data_df.head()
# Out:
#                                            questions    a       b
# 0  What are the special things we (husband and me...  TTD  TTDSIG
# 1  What are the companies which organize shark fe...  TTD  TTDOTH
# 2  Is it safe for female traveller to go alone to...  TGU  TGUHEA
# 3  What are the best places around Cape Town for ...  TTD  TTDSIG
# 4  What are the best places to stay for a family ...  ACM  ACMOTH

# %% [markdown]
# # Text Preprocessing

# %%
stop_words = set(stopwords.words('english')) 

def remove_stopwords(text):
  word_tokens = nltk.word_tokenize(text) 
  filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  return " ".join(filtered_sentence)

# %%
# Remove all the special characters
data_df['processed_questions'] = data_df['questions'].str.replace(r'\W', ' ')
    # remove all single characters
data_df['processed_questions'] = data_df['processed_questions'].str.replace(r'\s+[a-zA-Z]\s+', ' ')
    # Remove single characters from the start
data_df['processed_questions'] = data_df['questions'].str.replace(r'\^[a-zA-Z]\s+', ' ')
    # Substituting multiple spaces with single space
data_df['processed_questions'] = data_df['questions'].str.replace(r'\s+', ' ')
    # Removing prefixed 'b'
data_df['processed_questions'] = data_df['questions'].str.replace(r'^b\s+', '')
    # Remove leading, trailing spaces
data_df['processed_questions'] = data_df['questions'].str.strip()
# Stop word removal
data_df['sw_removed_questions'] = data_df.processed_questions.apply(remove_stopwords)

# %%
# Remove all the special characters
data_df['processed_a'] = data_df['a'].str.replace(r'\W', ' ')
    # remove all single characters
data_df['processed_a'] = data_df['a'].str.replace(r'\s+[a-zA-Z]\s+', ' ')
    # Remove single characters from the start
data_df['processed_a'] = data_df['a'].str.replace(r'\^[a-zA-Z]\s+', ' ')
    # Substituting multiple spaces with single space
data_df['processed_a'] = data_df['a'].str.replace(r'\s+', ' ')
    # Removing prefixed 'b'
data_df['processed_a'] = data_df['a'].str.replace(r'^b\s+', '')
    # Remove leading, trailing spaces
data_df['processed_a'] = data_df['a'].str.strip()

# %% [markdown]
# ## Lemmatizing

# %%
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
  lem = [lemmatizer.lemmatize(w, pos="v") for w in nltk.word_tokenize(text)]
  return " ".join(lem)

# %%
data_df["question_lemmatized_sw"] = data_df.sw_removed_questions.apply(lemmatize_text)

# %%
data_df.head()
# Out:
#                                            questions  ...                             question_lemmatized_sw
# 0  What are the special things we (husband and me...  ...  What special things ( husband ) 5 day stay Cap...
# 1  What are the companies which organize shark fe...  ...  What company organize shark feed events scuba ...
# 2  Is it safe for female traveller to go alone to...  ...      Is safe female traveller go alone Cape Town ?
# 3  What are the best places around Cape Town for ...  ...          What best place around Cape Town safari ?
# 4  What are the best places to stay for a family ...  ...  What best place stay family stay away nightlife ?
#
# [5 rows x 7 columns]

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


def print_report(y_test, y_pred):
    # Classification Report
    print(classification_report(y_test,y_pred))

    acc = accuracy_score(y_test, y_pred)*100
    print('Accuracy score: %.3f' % acc)

    f1_sc =  f1_score(y_test, y_pred, average='weighted')
    print('F1 Score: %.3f' % f1_sc)
    
    cm = confusion_matrix(y_test, y_pred)
    print("Confustion matrix: \n{}".format(cm))
    return f1_sc

# %% [markdown]
# # Data encoding

# %%
Y = data_df.processed_a.values
le = LabelEncoder()
Y = le.fit_transform(Y)
Y
# Out:
# array([5, 5, 3, ..., 0, 5, 4])

# %%
max_words = 5000
max_len = 25
tok = Tokenizer(num_words=max_words, split=' ')
tok.fit_on_texts(data_df.processed_questions.values)
sequences = tok.texts_to_sequences(data_df.processed_questions.values)
sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

# %%
sequences_matrix.shape
# Out:
# (5000, 25)

# %%
print(sequences_matrix[0])
print(Y[0])
# Out:
# [   0    0    0    0    0    0    4    7    2  321  105   31 1837   17
#    68    9   20   71    6  194   48   32   22  376  111]
# 5

# %% [markdown]
# # Model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import SpatialDropout1D
def LSTM_MODEL():
    model = Sequential()
    model.add(Embedding(5000, 160, input_length=sequences_matrix.shape[1]))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(196, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(7, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
y_nn = pd.get_dummies(data_df['processed_a']).values
y_nn.shape
# Out:
# (5000, 7)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


cv = KFold(n_splits=10, random_state=1, shuffle=True)
fold = 0
accuracies = []
for train_index, test_index in cv.split(sequences):
    print('***********************************************************')
    fold += 1
    X_train, X_test = sequences_matrix[train_index], sequences_matrix[test_index]
    y_train, y_test = y_nn[train_index], y_nn[test_index]
    print("Beginning fold: ", fold)

    model = LSTM_MODEL()
    model.fit(X_train, y_train, epochs=10, batch_size=64,validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
    
    predictions = model.predict(X_test)

    fine_pred = [np.argmax(p) for p in predictions]
    fine_gt = [np.argmax(p) for p in y_test]
    f1 = print_report(fine_pred, fine_gt)
    accuracies.append(f1)

print("Mean {:.2f} Std {:.2f}".format(np.mean(accuracies), np.std(accuracies)))
# Out:
# ***********************************************************
# Beginning fold:  1
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 124ms/step - loss: 1.6833 - accuracy: 0.3185 - val_loss: 1.7454 - val_accuracy: 0.1556
# Epoch 2/10
# 64/64 [==============================] - 7s 116ms/step - loss: 1.0336 - accuracy: 0.6383 - val_loss: 1.0355 - val_accuracy: 0.6844
# Epoch 3/10
# 64/64 [==============================] - 7s 115ms/step - loss: 0.5376 - accuracy: 0.8262 - val_loss: 0.8211 - val_accuracy: 0.7756
# Epoch 4/10
# 64/64 [==============================] - 7s 114ms/step - loss: 0.2960 - accuracy: 0.9170 - val_loss: 0.9495 - val_accuracy: 0.6956
# Epoch 5/10
# 64/64 [==============================] - 7s 115ms/step - loss: 0.1775 - accuracy: 0.9538 - val_loss: 0.8396 - val_accuracy: 0.7889
# Epoch 6/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.1067 - accuracy: 0.9716 - val_loss: 1.0367 - val_accuracy: 0.7067
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        81
#            1       0.68      0.53      0.60        32
#            2       0.75      0.91      0.82        46
#            3       0.86      0.72      0.78       127
#            4       0.92      0.86      0.89       102
#            5       0.70      0.84      0.76        99
#            6       0.72      1.00      0.84        13
#
#     accuracy                           0.80       500
#    macro avg       0.78      0.81      0.79       500
# weighted avg       0.81      0.80      0.80       500
#
# Accuracy score: 80.400
# F1 Score: 0.803
# Confustion matrix:
# [[68  0  3  4  0  5  1]
#  [ 1 17  3  1  0  9  1]
#  [ 2  1 42  1  0  0  0]
#  [ 8  1  4 91  6 16  1]
#  [ 1  2  1  5 88  5  0]
#  [ 1  4  3  4  2 83  2]
#  [ 0  0  0  0  0  0 13]]
# ***********************************************************
# Beginning fold:  2
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 126ms/step - loss: 1.6716 - accuracy: 0.3222 - val_loss: 1.5640 - val_accuracy: 0.4956
# Epoch 2/10
# 64/64 [==============================] - 8s 119ms/step - loss: 1.0449 - accuracy: 0.6494 - val_loss: 1.1963 - val_accuracy: 0.5733
# Epoch 3/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.5080 - accuracy: 0.8405 - val_loss: 0.8092 - val_accuracy: 0.7844
# Epoch 4/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.2805 - accuracy: 0.9210 - val_loss: 0.9310 - val_accuracy: 0.7244
# Epoch 5/10
# 64/64 [==============================] - 7s 115ms/step - loss: 0.1551 - accuracy: 0.9565 - val_loss: 0.7750 - val_accuracy: 0.7622
# Epoch 6/10
# 64/64 [==============================] - 7s 115ms/step - loss: 0.0908 - accuracy: 0.9756 - val_loss: 0.8408 - val_accuracy: 0.7733
# Epoch 7/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0726 - accuracy: 0.9800 - val_loss: 1.1551 - val_accuracy: 0.6733
# Epoch 8/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.0671 - accuracy: 0.9837 - val_loss: 0.9931 - val_accuracy: 0.7422
#               precision    recall  f1-score   support
#
#            0       0.91      0.80      0.85        94
#            1       0.52      0.87      0.65        15
#            2       0.92      0.82      0.87        44
#            3       0.85      0.80      0.82       131
#            4       0.81      0.87      0.84        87
#            5       0.80      0.79      0.80       112
#            6       0.68      1.00      0.81        17
#
#     accuracy                           0.82       500
#    macro avg       0.78      0.85      0.81       500
# weighted avg       0.83      0.82      0.82       500
#
# Accuracy score: 82.200
# F1 Score: 0.824
# Confustion matrix:
# [[ 75   3   2   4   3   6   1]
#  [  0  13   0   0   0   0   2]
#  [  1   2  36   2   0   2   1]
#  [  3   0   0 105  10  11   2]
#  [  0   0   0   7  76   3   1]
#  [  3   7   1   6   5  89   1]
#  [  0   0   0   0   0   0  17]]
# ***********************************************************
# Beginning fold:  3
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 124ms/step - loss: 1.6885 - accuracy: 0.3341 - val_loss: 1.7402 - val_accuracy: 0.2422
# Epoch 2/10
# 64/64 [==============================] - 8s 121ms/step - loss: 1.0338 - accuracy: 0.6378 - val_loss: 0.9862 - val_accuracy: 0.6644
# Epoch 3/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.4925 - accuracy: 0.8558 - val_loss: 0.9324 - val_accuracy: 0.7244
# Epoch 4/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.2819 - accuracy: 0.9185 - val_loss: 0.9006 - val_accuracy: 0.7378
# Epoch 5/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.1484 - accuracy: 0.9595 - val_loss: 0.7693 - val_accuracy: 0.7889
# Epoch 6/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0873 - accuracy: 0.9748 - val_loss: 0.7654 - val_accuracy: 0.7800
# Epoch 7/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.0582 - accuracy: 0.9827 - val_loss: 0.8477 - val_accuracy: 0.7911
# Epoch 8/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.0492 - accuracy: 0.9874 - val_loss: 0.9364 - val_accuracy: 0.7867
# Epoch 9/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.0292 - accuracy: 0.9923 - val_loss: 0.7982 - val_accuracy: 0.8067
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77        61
#            1       0.69      0.52      0.59        21
#            2       0.87      0.90      0.88        50
#            3       0.73      0.72      0.72       128
#            4       0.87      0.90      0.89        94
#            5       0.79      0.73      0.76       131
#            6       0.81      0.87      0.84        15
#
#     accuracy                           0.78       500
#    macro avg       0.78      0.78      0.78       500
# weighted avg       0.78      0.78      0.78       500
#
# Accuracy score: 78.400
# F1 Score: 0.782
# Confustion matrix:
# [[51  1  1  4  1  2  1]
#  [ 0 11  3  2  0  5  0]
#  [ 3  0 45  1  0  1  0]
#  [10  1  1 92  8 15  1]
#  [ 1  0  0  7 85  1  0]
#  [ 7  3  2 19  4 95  1]
#  [ 0  0  0  1  0  1 13]]
# ***********************************************************
# Beginning fold:  4
# WARNING:tensorflow:Layer lstm_37 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 122ms/step - loss: 1.6651 - accuracy: 0.3279 - val_loss: 1.6486 - val_accuracy: 0.2956
# Epoch 2/10
# 64/64 [==============================] - 8s 122ms/step - loss: 1.0588 - accuracy: 0.6383 - val_loss: 1.0725 - val_accuracy: 0.6533
# Epoch 3/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.5364 - accuracy: 0.8314 - val_loss: 0.8186 - val_accuracy: 0.7667
# Epoch 4/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.2668 - accuracy: 0.9274 - val_loss: 0.7783 - val_accuracy: 0.7622
# Epoch 5/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.1612 - accuracy: 0.9543 - val_loss: 0.8480 - val_accuracy: 0.7600
# Epoch 6/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.1015 - accuracy: 0.9691 - val_loss: 0.8827 - val_accuracy: 0.7089
# Epoch 7/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.0643 - accuracy: 0.9854 - val_loss: 0.8983 - val_accuracy: 0.7511
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81        80
#            1       0.46      0.69      0.55        16
#            2       0.82      0.90      0.86        52
#            3       0.78      0.80      0.79       121
#            4       0.86      0.85      0.86       103
#            5       0.81      0.76      0.79       113
#            6       0.82      0.93      0.87        15
#
#     accuracy                           0.81       500
#    macro avg       0.78      0.81      0.79       500
# weighted avg       0.81      0.81      0.81       500
#
# Accuracy score: 80.800
# F1 Score: 0.810
# Confustion matrix:
# [[61  3  5  5  1  5  0]
#  [ 0 11  1  2  0  1  1]
#  [ 1  2 47  0  1  1  0]
#  [ 6  1  2 97  6  8  1]
#  [ 1  0  0  9 88  5  0]
#  [ 1  6  2 11  6 86  1]
#  [ 0  1  0  0  0  0 14]]
# ***********************************************************
# Beginning fold:  5
# WARNING:tensorflow:Layer lstm_38 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 124ms/step - loss: 1.6868 - accuracy: 0.3074 - val_loss: 1.6645 - val_accuracy: 0.2844
# Epoch 2/10
# 64/64 [==============================] - 8s 119ms/step - loss: 1.0494 - accuracy: 0.6425 - val_loss: 1.1968 - val_accuracy: 0.5956
# Epoch 3/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.4972 - accuracy: 0.8462 - val_loss: 0.9230 - val_accuracy: 0.7133
# Epoch 4/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.2686 - accuracy: 0.9207 - val_loss: 0.9852 - val_accuracy: 0.6911
# Epoch 5/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.1522 - accuracy: 0.9583 - val_loss: 0.8125 - val_accuracy: 0.7467
# Epoch 6/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.1006 - accuracy: 0.9733 - val_loss: 0.7442 - val_accuracy: 0.7911
# Epoch 7/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.0709 - accuracy: 0.9835 - val_loss: 0.9245 - val_accuracy: 0.7333
# Epoch 8/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.0455 - accuracy: 0.9891 - val_loss: 0.7772 - val_accuracy: 0.7711
# Epoch 9/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.0411 - accuracy: 0.9879 - val_loss: 1.0233 - val_accuracy: 0.7556
#               precision    recall  f1-score   support
#
#            0       0.88      0.68      0.77        73
#            1       0.60      0.69      0.64        26
#            2       0.88      0.88      0.88        49
#            3       0.73      0.82      0.77       111
#            4       0.89      0.88      0.89       111
#            5       0.68      0.66      0.67       119
#            6       0.67      0.91      0.77        11
#
#     accuracy                           0.78       500
#    macro avg       0.76      0.79      0.77       500
# weighted avg       0.78      0.78      0.78       500
#
# Accuracy score: 77.600
# F1 Score: 0.776
# Confustion matrix:
# [[50  1  0  5  0 17  0]
#  [ 2 18  0  0  1  4  1]
#  [ 1  1 43  2  0  2  0]
#  [ 2  0  3 91  4 10  1]
#  [ 0  2  1  8 98  2  0]
#  [ 2  8  2 19  7 78  3]
#  [ 0  0  0  0  0  1 10]]
# ***********************************************************
# Beginning fold:  6
# WARNING:tensorflow:Layer lstm_39 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 128ms/step - loss: 1.7128 - accuracy: 0.2980 - val_loss: 1.6323 - val_accuracy: 0.3400
# Epoch 2/10
# 64/64 [==============================] - 8s 121ms/step - loss: 1.0886 - accuracy: 0.6151 - val_loss: 1.0222 - val_accuracy: 0.6978
# Epoch 3/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.5053 - accuracy: 0.8435 - val_loss: 0.8309 - val_accuracy: 0.7556
# Epoch 4/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.2716 - accuracy: 0.9173 - val_loss: 0.7249 - val_accuracy: 0.7889
# Epoch 5/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.1447 - accuracy: 0.9583 - val_loss: 0.7325 - val_accuracy: 0.7644
# Epoch 6/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0813 - accuracy: 0.9748 - val_loss: 0.7121 - val_accuracy: 0.7778
# Epoch 7/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0607 - accuracy: 0.9849 - val_loss: 0.6799 - val_accuracy: 0.7956
# Epoch 8/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0383 - accuracy: 0.9894 - val_loss: 0.6695 - val_accuracy: 0.8133
# Epoch 9/10
# 64/64 [==============================] - 8s 126ms/step - loss: 0.0303 - accuracy: 0.9936 - val_loss: 0.8406 - val_accuracy: 0.7711
# Epoch 10/10
# 64/64 [==============================] - 8s 123ms/step - loss: 0.0315 - accuracy: 0.9928 - val_loss: 0.8299 - val_accuracy: 0.7733
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78        66
#            1       0.71      0.56      0.63        18
#            2       0.82      0.91      0.86        45
#            3       0.79      0.83      0.81       141
#            4       0.90      0.91      0.90       109
#            5       0.77      0.77      0.77       101
#            6       0.89      0.80      0.84        20
#
#     accuracy                           0.82       500
#    macro avg       0.82      0.79      0.80       500
# weighted avg       0.82      0.82      0.82       500
#
# Accuracy score: 82.000
# F1 Score: 0.819
# Confustion matrix:
# [[ 49   1   2   7   1   6   0]
#  [  2  10   3   1   0   2   0]
#  [  2   0  41   2   0   0   0]
#  [  4   0   0 117   8  11   1]
#  [  0   0   0   8  99   1   1]
#  [  2   3   4  12   2  78   0]
#  [  0   0   0   1   0   3  16]]
# ***********************************************************
# Beginning fold:  7
# WARNING:tensorflow:Layer lstm_40 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 129ms/step - loss: 1.6889 - accuracy: 0.3279 - val_loss: 1.5950 - val_accuracy: 0.4333
# Epoch 2/10
# 64/64 [==============================] - 8s 119ms/step - loss: 1.0311 - accuracy: 0.6533 - val_loss: 0.9831 - val_accuracy: 0.6733
# Epoch 3/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.5211 - accuracy: 0.8328 - val_loss: 0.7734 - val_accuracy: 0.7711
# Epoch 4/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.2727 - accuracy: 0.9195 - val_loss: 0.7410 - val_accuracy: 0.7667
# Epoch 5/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.1601 - accuracy: 0.9553 - val_loss: 0.7581 - val_accuracy: 0.7356
# Epoch 6/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0892 - accuracy: 0.9743 - val_loss: 0.7916 - val_accuracy: 0.7444
# Epoch 7/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.0580 - accuracy: 0.9847 - val_loss: 0.8150 - val_accuracy: 0.7511
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        80
#            1       0.60      0.68      0.64        22
#            2       0.86      0.93      0.89        40
#            3       0.83      0.68      0.75       133
#            4       0.92      0.88      0.90       102
#            5       0.74      0.77      0.76       115
#            6       0.53      1.00      0.70         8
#
#     accuracy                           0.80       500
#    macro avg       0.75      0.83      0.78       500
# weighted avg       0.81      0.80      0.80       500
#
# Accuracy score: 80.000
# F1 Score: 0.800
# Confustion matrix:
# [[70  0  1  5  0  3  1]
#  [ 0 15  1  0  0  4  2]
#  [ 1  1 37  0  0  1  0]
#  [11  4  1 91  6 19  1]
#  [ 1  1  0  5 90  4  1]
#  [ 6  4  3  9  2 89  2]
#  [ 0  0  0  0  0  0  8]]
# ***********************************************************
# Beginning fold:  8
# WARNING:tensorflow:Layer lstm_41 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 128ms/step - loss: 1.6741 - accuracy: 0.3242 - val_loss: 1.6933 - val_accuracy: 0.3511
# Epoch 2/10
# 64/64 [==============================] - 8s 122ms/step - loss: 1.0964 - accuracy: 0.6022 - val_loss: 1.3295 - val_accuracy: 0.4800
# Epoch 3/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.5706 - accuracy: 0.8165 - val_loss: 0.7883 - val_accuracy: 0.7911
# Epoch 4/10
# 64/64 [==============================] - 8s 124ms/step - loss: 0.3070 - accuracy: 0.9062 - val_loss: 0.8757 - val_accuracy: 0.7244
# Epoch 5/10
# 64/64 [==============================] - 8s 125ms/step - loss: 0.1783 - accuracy: 0.9491 - val_loss: 0.7112 - val_accuracy: 0.7933
# Epoch 6/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.1047 - accuracy: 0.9731 - val_loss: 0.8141 - val_accuracy: 0.7444
# Epoch 7/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0737 - accuracy: 0.9780 - val_loss: 0.7926 - val_accuracy: 0.7578
# Epoch 8/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0465 - accuracy: 0.9879 - val_loss: 0.8759 - val_accuracy: 0.7489
#               precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87        72
#            1       0.62      0.71      0.67        14
#            2       0.89      0.87      0.88        62
#            3       0.65      0.77      0.71       100
#            4       0.92      0.86      0.89       117
#            5       0.72      0.72      0.72       116
#            6       0.71      0.63      0.67        19
#
#     accuracy                           0.79       500
#    macro avg       0.78      0.77      0.77       500
# weighted avg       0.80      0.79      0.79       500
#
# Accuracy score: 79.200
# F1 Score: 0.795
# Confustion matrix:
# [[ 59   0   0   8   2   3   0]
#  [  0  10   0   2   0   2   0]
#  [  0   3  54   1   1   3   0]
#  [  1   0   2  77   2  17   1]
#  [  1   0   0   9 101   6   0]
#  [  2   3   5  15   4  83   4]
#  [  0   0   0   6   0   1  12]]
# ***********************************************************
# Beginning fold:  9
# WARNING:tensorflow:Layer lstm_42 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 125ms/step - loss: 1.6780 - accuracy: 0.3501 - val_loss: 1.6385 - val_accuracy: 0.1622
# Epoch 2/10
# 64/64 [==============================] - 8s 120ms/step - loss: 1.0400 - accuracy: 0.6321 - val_loss: 1.0514 - val_accuracy: 0.6778
# Epoch 3/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.4944 - accuracy: 0.8383 - val_loss: 0.8038 - val_accuracy: 0.7489
# Epoch 4/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.2779 - accuracy: 0.9163 - val_loss: 0.7990 - val_accuracy: 0.7600
# Epoch 5/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.1746 - accuracy: 0.9504 - val_loss: 0.7586 - val_accuracy: 0.7578
# Epoch 6/10
# 64/64 [==============================] - 8s 123ms/step - loss: 0.0895 - accuracy: 0.9783 - val_loss: 0.8880 - val_accuracy: 0.7244
# Epoch 7/10
# 64/64 [==============================] - 8s 123ms/step - loss: 0.0716 - accuracy: 0.9812 - val_loss: 0.9646 - val_accuracy: 0.7222
# Epoch 8/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0415 - accuracy: 0.9896 - val_loss: 1.0555 - val_accuracy: 0.7000
#               precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83        86
#            1       0.56      0.43      0.49        23
#            2       0.91      0.82      0.86        60
#            3       0.73      0.82      0.77       114
#            4       0.92      0.86      0.89       101
#            5       0.71      0.82      0.76       105
#            6       0.71      0.91      0.80        11
#
#     accuracy                           0.80       500
#    macro avg       0.78      0.77      0.77       500
# weighted avg       0.81      0.80      0.80       500
#
# Accuracy score: 80.000
# F1 Score: 0.801
# Confustion matrix:
# [[65  1  3  8  0  9  0]
#  [ 1 10  0  2  0  9  1]
#  [ 1  3 49  3  0  4  0]
#  [ 2  2  1 93  8  7  1]
#  [ 1  0  0  7 87  6  0]
#  [ 1  2  1 13  0 86  2]
#  [ 0  0  0  1  0  0 10]]
# ***********************************************************
# Beginning fold:  10
# WARNING:tensorflow:Layer lstm_43 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 128ms/step - loss: 1.6522 - accuracy: 0.3469 - val_loss: 1.5293 - val_accuracy: 0.3889
# Epoch 2/10
# 64/64 [==============================] - 8s 123ms/step - loss: 0.9846 - accuracy: 0.6585 - val_loss: 0.9530 - val_accuracy: 0.7267
# Epoch 3/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.4968 - accuracy: 0.8415 - val_loss: 0.8312 - val_accuracy: 0.7622
# Epoch 4/10
# 64/64 [==============================] - 8s 123ms/step - loss: 0.2858 - accuracy: 0.9215 - val_loss: 0.8163 - val_accuracy: 0.7578
# Epoch 5/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.1809 - accuracy: 0.9489 - val_loss: 0.7864 - val_accuracy: 0.7689
# Epoch 6/10
# 64/64 [==============================] - 8s 124ms/step - loss: 0.1045 - accuracy: 0.9741 - val_loss: 0.7400 - val_accuracy: 0.7978
# Epoch 7/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.0708 - accuracy: 0.9827 - val_loss: 0.7678 - val_accuracy: 0.7822
# Epoch 8/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.0659 - accuracy: 0.9820 - val_loss: 0.7920 - val_accuracy: 0.7956
# Epoch 9/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0624 - accuracy: 0.9837 - val_loss: 0.8003 - val_accuracy: 0.7622
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        76
#            1       0.70      0.76      0.73        21
#            2       0.80      0.92      0.86        52
#            3       0.77      0.81      0.79       106
#            4       0.83      0.85      0.84        95
#            5       0.86      0.73      0.79       135
#            6       0.82      0.93      0.87        15
#
#     accuracy                           0.82       500
#    macro avg       0.80      0.84      0.82       500
# weighted avg       0.82      0.82      0.82       500
#
# Accuracy score: 81.600
# F1 Score: 0.815
# Confustion matrix:
# [[65  0  3  2  3  3  0]
#  [ 0 16  2  0  0  3  0]
#  [ 1  1 48  2  0  0  0]
#  [ 4  2  2 86  4  7  1]
#  [ 0  0  0 10 81  3  1]
#  [ 6  4  5 11 10 98  1]
#  [ 0  0  0  1  0  0 14]]
# Mean 0.80 Std 0.01

# %%
# max_words = 5000
# max_len = 25
# tok = Tokenizer(num_words=max_words, split=' ')
# tok.fit_on_texts(data_df.processed_questions.values)
# sequences = tok.texts_to_sequences(data_df.processed_questions.values)
# sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

tok1 = Tokenizer(num_words=max_words, split=' ')
tok1.fit_on_texts(data_df.question_lemmatized_sw.values)
sequences_lem_sw = tok1.texts_to_sequences(data_df.question_lemmatized_sw.values)
sequences_matrix_lem_sw = sequence.pad_sequences(sequences_lem_sw,maxlen=max_len)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


cv = KFold(n_splits=10, random_state=1, shuffle=True)
fold = 0
accuracies = []
for train_index, test_index in cv.split(sequences_lem_sw):
    print('***********************************************************')
    fold += 1
    X_train, X_test = sequences_matrix_lem_sw[train_index], sequences_matrix_lem_sw[test_index]
    y_train, y_test = y_nn[train_index], y_nn[test_index]
    print("Beginning fold: ", fold)

    model = LSTM_MODEL()
    model.fit(X_train, y_train, epochs=10, batch_size=64,validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
    predictions = model.predict(X_test)
    fine_pred = [np.argmax(p) for p in predictions]
    fine_gt = [np.argmax(p) for p in y_test]
    f1 = print_report(fine_pred, fine_gt)
    accuracies.append(f1)

print("Mean {:.2f} Std {:.2f}".format(np.mean(accuracies), np.std(accuracies)))
# Out:
# ***********************************************************
# Beginning fold:  1
# WARNING:tensorflow:Layer lstm_44 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 120ms/step - loss: 1.7147 - accuracy: 0.2901 - val_loss: 1.6584 - val_accuracy: 0.4911
# Epoch 2/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.9621 - accuracy: 0.6877 - val_loss: 1.1725 - val_accuracy: 0.6089
# Epoch 3/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.4435 - accuracy: 0.8612 - val_loss: 0.9728 - val_accuracy: 0.7044
# Epoch 4/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.2276 - accuracy: 0.9365 - val_loss: 0.9973 - val_accuracy: 0.6867
# Epoch 5/10
# 64/64 [==============================] - 7s 115ms/step - loss: 0.1153 - accuracy: 0.9689 - val_loss: 0.8915 - val_accuracy: 0.7422
# Epoch 6/10
# 64/64 [==============================] - 7s 115ms/step - loss: 0.0657 - accuracy: 0.9852 - val_loss: 0.9317 - val_accuracy: 0.7467
# Epoch 7/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.0467 - accuracy: 0.9867 - val_loss: 1.0419 - val_accuracy: 0.7422
# Epoch 8/10
# 64/64 [==============================] - 7s 114ms/step - loss: 0.0362 - accuracy: 0.9904 - val_loss: 1.0562 - val_accuracy: 0.7067
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88        83
#            1       0.72      0.67      0.69        27
#            2       0.84      0.94      0.89        50
#            3       0.84      0.81      0.82       110
#            4       0.94      0.81      0.87       111
#            5       0.76      0.87      0.81       103
#            6       0.78      0.88      0.82        16
#
#     accuracy                           0.84       500
#    macro avg       0.82      0.83      0.83       500
# weighted avg       0.85      0.84      0.84       500
#
# Accuracy score: 84.000
# F1 Score: 0.840
# Confustion matrix:
# [[72  0  2  5  0  4  0]
#  [ 0 18  2  0  0  7  0]
#  [ 1  2 47  0  0  0  0]
#  [ 2  1  3 89  3 11  1]
#  [ 3  3  1  8 90  5  1]
#  [ 3  1  1  3  3 90  2]
#  [ 0  0  0  1  0  1 14]]
# ***********************************************************
# Beginning fold:  2
# WARNING:tensorflow:Layer lstm_45 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 121ms/step - loss: 1.7074 - accuracy: 0.3109 - val_loss: 1.6964 - val_accuracy: 0.3356
# Epoch 2/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.9465 - accuracy: 0.6990 - val_loss: 1.2931 - val_accuracy: 0.5356
# Epoch 3/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.4604 - accuracy: 0.8496 - val_loss: 0.9652 - val_accuracy: 0.7156
# Epoch 4/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.2434 - accuracy: 0.9304 - val_loss: 0.7966 - val_accuracy: 0.7644
# Epoch 5/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.1286 - accuracy: 0.9630 - val_loss: 0.9113 - val_accuracy: 0.7422
# Epoch 6/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.0798 - accuracy: 0.9795 - val_loss: 0.9334 - val_accuracy: 0.7267
# Epoch 7/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0461 - accuracy: 0.9899 - val_loss: 0.9890 - val_accuracy: 0.7244
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88        83
#            1       0.60      1.00      0.75        15
#            2       0.92      0.86      0.89        42
#            3       0.82      0.78      0.80       131
#            4       0.85      0.78      0.82       102
#            5       0.76      0.77      0.76       109
#            6       0.68      0.94      0.79        18
#
#     accuracy                           0.81       500
#    macro avg       0.79      0.86      0.81       500
# weighted avg       0.82      0.81      0.82       500
#
# Accuracy score: 81.400
# F1 Score: 0.815
# Confustion matrix:
# [[ 73   1   1   2   2   4   0]
#  [  0  15   0   0   0   0   0]
#  [  1   2  36   1   0   2   0]
#  [  4   0   1 102   8  14   2]
#  [  1   0   0  10  80   7   4]
#  [  3   6   1   9   4  84   2]
#  [  0   1   0   0   0   0  17]]
# ***********************************************************
# Beginning fold:  3
# WARNING:tensorflow:Layer lstm_46 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 121ms/step - loss: 1.7315 - accuracy: 0.2874 - val_loss: 1.6142 - val_accuracy: 0.5933
# Epoch 2/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.9588 - accuracy: 0.6889 - val_loss: 1.0414 - val_accuracy: 0.6489
# Epoch 3/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.4361 - accuracy: 0.8627 - val_loss: 1.0135 - val_accuracy: 0.7222
# Epoch 4/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.2145 - accuracy: 0.9358 - val_loss: 0.8680 - val_accuracy: 0.7556
# Epoch 5/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.1041 - accuracy: 0.9714 - val_loss: 0.9903 - val_accuracy: 0.7400
# Epoch 6/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.0678 - accuracy: 0.9817 - val_loss: 0.9105 - val_accuracy: 0.7378
# Epoch 7/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0427 - accuracy: 0.9899 - val_loss: 0.8600 - val_accuracy: 0.7533
# Epoch 8/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.0304 - accuracy: 0.9916 - val_loss: 1.2412 - val_accuracy: 0.7422
# Epoch 9/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0240 - accuracy: 0.9951 - val_loss: 1.2386 - val_accuracy: 0.7244
# Epoch 10/10
# 64/64 [==============================] - 8s 124ms/step - loss: 0.0216 - accuracy: 0.9958 - val_loss: 1.1142 - val_accuracy: 0.7289
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83        82
#            1       0.81      0.57      0.67        23
#            2       0.75      0.95      0.84        41
#            3       0.69      0.81      0.74       108
#            4       0.97      0.79      0.87       120
#            5       0.73      0.78      0.76       113
#            6       0.75      0.92      0.83        13
#
#     accuracy                           0.80       500
#    macro avg       0.80      0.80      0.79       500
# weighted avg       0.81      0.80      0.80       500
#
# Accuracy score: 79.600
# F1 Score: 0.798
# Confustion matrix:
# [[64  0  3  9  0  6  0]
#  [ 0 13  2  3  1  3  1]
#  [ 0  0 39  0  0  2  0]
#  [ 5  0  2 87  1 11  2]
#  [ 1  1  3 10 95 10  0]
#  [ 2  2  3 16  1 88  1]
#  [ 0  0  0  1  0  0 12]]
# ***********************************************************
# Beginning fold:  4
# WARNING:tensorflow:Layer lstm_47 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 127ms/step - loss: 1.7357 - accuracy: 0.3067 - val_loss: 1.8584 - val_accuracy: 0.2422
# Epoch 2/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.9438 - accuracy: 0.6980 - val_loss: 1.0092 - val_accuracy: 0.6822
# Epoch 3/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.4244 - accuracy: 0.8768 - val_loss: 0.8252 - val_accuracy: 0.7711
# Epoch 4/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.2131 - accuracy: 0.9398 - val_loss: 0.9157 - val_accuracy: 0.6978
# Epoch 5/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.1288 - accuracy: 0.9679 - val_loss: 0.7454 - val_accuracy: 0.7733
# Epoch 6/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.0703 - accuracy: 0.9817 - val_loss: 0.8508 - val_accuracy: 0.7289
# Epoch 7/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0530 - accuracy: 0.9891 - val_loss: 1.1601 - val_accuracy: 0.6711
# Epoch 8/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.0333 - accuracy: 0.9921 - val_loss: 1.0619 - val_accuracy: 0.7133
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78        68
#            1       0.71      0.65      0.68        26
#            2       0.88      0.93      0.90        54
#            3       0.81      0.74      0.77       135
#            4       0.86      0.86      0.86       102
#            5       0.74      0.79      0.76        99
#            6       0.82      0.88      0.85        16
#
#     accuracy                           0.80       500
#    macro avg       0.80      0.81      0.80       500
# weighted avg       0.80      0.80      0.80       500
#
# Accuracy score: 80.200
# F1 Score: 0.801
# Confustion matrix:
# [[ 54   3   1   5   2   3   0]
#  [  2  17   1   1   0   4   1]
#  [  1   0  50   0   0   3   0]
#  [  6   0   4 100   7  16   2]
#  [  2   0   0  10  88   2   0]
#  [  5   2   1   8   5  78   0]
#  [  0   2   0   0   0   0  14]]
# ***********************************************************
# Beginning fold:  5
# WARNING:tensorflow:Layer lstm_48 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 122ms/step - loss: 1.7526 - accuracy: 0.2906 - val_loss: 1.7698 - val_accuracy: 0.3244
# Epoch 2/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.9515 - accuracy: 0.6936 - val_loss: 1.1842 - val_accuracy: 0.6067
# Epoch 3/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.4011 - accuracy: 0.8696 - val_loss: 0.9108 - val_accuracy: 0.7400
# Epoch 4/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.2088 - accuracy: 0.9405 - val_loss: 0.8883 - val_accuracy: 0.7356
# Epoch 5/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.1145 - accuracy: 0.9686 - val_loss: 0.9666 - val_accuracy: 0.7022
# Epoch 6/10
# 64/64 [==============================] - 7s 115ms/step - loss: 0.0744 - accuracy: 0.9795 - val_loss: 1.0090 - val_accuracy: 0.7222
# Epoch 7/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.0506 - accuracy: 0.9874 - val_loss: 0.9887 - val_accuracy: 0.6911
#               precision    recall  f1-score   support
#
#            0       0.91      0.61      0.73        85
#            1       0.77      0.72      0.74        32
#            2       0.86      0.88      0.87        48
#            3       0.73      0.76      0.75       119
#            4       0.90      0.88      0.89       112
#            5       0.58      0.73      0.64        91
#            6       0.73      0.85      0.79        13
#
#     accuracy                           0.77       500
#    macro avg       0.78      0.78      0.77       500
# weighted avg       0.79      0.77      0.77       500
#
# Accuracy score: 76.800
# F1 Score: 0.770
# Confustion matrix:
# [[52  2  1  9  2 19  0]
#  [ 2 23  0  0  1  5  1]
#  [ 0  1 42  2  0  3  0]
#  [ 1  1  3 91  5 17  1]
#  [ 0  1  1  7 99  3  1]
#  [ 2  2  2 16  2 66  1]
#  [ 0  0  0  0  1  1 11]]
# ***********************************************************
# Beginning fold:  6
# WARNING:tensorflow:Layer lstm_49 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 124ms/step - loss: 1.7226 - accuracy: 0.3072 - val_loss: 1.8900 - val_accuracy: 0.0978
# Epoch 2/10
# 64/64 [==============================] - 7s 116ms/step - loss: 0.9860 - accuracy: 0.6721 - val_loss: 1.1943 - val_accuracy: 0.6089
# Epoch 3/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.4608 - accuracy: 0.8620 - val_loss: 0.7856 - val_accuracy: 0.7667
# Epoch 4/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.2405 - accuracy: 0.9351 - val_loss: 0.8817 - val_accuracy: 0.7689
# Epoch 5/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.1381 - accuracy: 0.9607 - val_loss: 0.8621 - val_accuracy: 0.7289
# Epoch 6/10
# 64/64 [==============================] - 8s 117ms/step - loss: 0.0787 - accuracy: 0.9810 - val_loss: 0.8420 - val_accuracy: 0.7356
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81        62
#            1       0.79      0.79      0.79        14
#            2       0.92      0.90      0.91        51
#            3       0.74      0.85      0.79       129
#            4       0.92      0.86      0.89       118
#            5       0.80      0.74      0.77       110
#            6       0.89      1.00      0.94        16
#
#     accuracy                           0.83       500
#    macro avg       0.84      0.85      0.84       500
# weighted avg       0.83      0.83      0.83       500
#
# Accuracy score: 82.800
# F1 Score: 0.828
# Confustion matrix:
# [[ 49   1   0   6   2   4   0]
#  [  1  11   1   0   0   1   0]
#  [  2   0  46   2   0   1   0]
#  [  4   0   1 110   2  11   1]
#  [  0   0   0  13 101   3   1]
#  [  3   2   2  17   5  81   0]
#  [  0   0   0   0   0   0  16]]
# ***********************************************************
# Beginning fold:  7
# WARNING:tensorflow:Layer lstm_50 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 124ms/step - loss: 1.7058 - accuracy: 0.3277 - val_loss: 1.7008 - val_accuracy: 0.2933
# Epoch 2/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.9248 - accuracy: 0.7067 - val_loss: 1.2168 - val_accuracy: 0.6467
# Epoch 3/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.4259 - accuracy: 0.8733 - val_loss: 0.7842 - val_accuracy: 0.7533
# Epoch 4/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.2101 - accuracy: 0.9407 - val_loss: 0.7583 - val_accuracy: 0.7511
# Epoch 5/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.1107 - accuracy: 0.9719 - val_loss: 0.7683 - val_accuracy: 0.7844
# Epoch 6/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.0664 - accuracy: 0.9812 - val_loss: 0.8860 - val_accuracy: 0.7333
# Epoch 7/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.0508 - accuracy: 0.9872 - val_loss: 0.8864 - val_accuracy: 0.7556
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        99
#            1       0.64      0.84      0.73        19
#            2       0.95      0.85      0.90        48
#            3       0.81      0.74      0.77       120
#            4       0.84      0.88      0.86        93
#            5       0.71      0.77      0.74       111
#            6       0.67      1.00      0.80        10
#
#     accuracy                           0.80       500
#    macro avg       0.79      0.84      0.81       500
# weighted avg       0.81      0.80      0.81       500
#
# Accuracy score: 80.400
# F1 Score: 0.805
# Confustion matrix:
# [[79  2  0  6  2  9  1]
#  [ 0 16  0  0  0  3  0]
#  [ 1  2 41  2  0  2  0]
#  [ 5  1  1 89  8 16  0]
#  [ 2  0  0  3 82  5  1]
#  [ 2  4  1 10  6 85  3]
#  [ 0  0  0  0  0  0 10]]
# ***********************************************************
# Beginning fold:  8
# WARNING:tensorflow:Layer lstm_51 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 127ms/step - loss: 1.7335 - accuracy: 0.3012 - val_loss: 2.1700 - val_accuracy: 0.0867
# Epoch 2/10
# 64/64 [==============================] - 8s 122ms/step - loss: 1.0106 - accuracy: 0.6681 - val_loss: 1.1849 - val_accuracy: 0.5978
# Epoch 3/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.4588 - accuracy: 0.8575 - val_loss: 0.8332 - val_accuracy: 0.7511
# Epoch 4/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.2322 - accuracy: 0.9331 - val_loss: 0.9737 - val_accuracy: 0.6822
# Epoch 5/10
# 64/64 [==============================] - 7s 117ms/step - loss: 0.1315 - accuracy: 0.9669 - val_loss: 0.8350 - val_accuracy: 0.7333
# Epoch 6/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0679 - accuracy: 0.9835 - val_loss: 0.9179 - val_accuracy: 0.7267
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        70
#            1       0.69      0.79      0.73        14
#            2       0.87      0.91      0.89        58
#            3       0.84      0.73      0.78       136
#            4       0.90      0.90      0.90       110
#            5       0.67      0.80      0.73        96
#            6       0.76      0.81      0.79        16
#
#     accuracy                           0.82       500
#    macro avg       0.80      0.82      0.81       500
# weighted avg       0.82      0.82      0.82       500
#
# Accuracy score: 81.600
# F1 Score: 0.817
# Confustion matrix:
# [[56  1  2  3  2  6  0]
#  [ 0 11  0  1  0  2  0]
#  [ 0  1 53  0  0  4  0]
#  [ 4  1  4 99  8 20  0]
#  [ 2  0  1  2 99  5  1]
#  [ 1  2  1 11  1 77  3]
#  [ 0  0  0  2  0  1 13]]
# ***********************************************************
# Beginning fold:  9
# WARNING:tensorflow:Layer lstm_52 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 128ms/step - loss: 1.7401 - accuracy: 0.2928 - val_loss: 1.6595 - val_accuracy: 0.1022
# Epoch 2/10
# 64/64 [==============================] - 8s 124ms/step - loss: 0.9639 - accuracy: 0.6795 - val_loss: 1.1398 - val_accuracy: 0.6289
# Epoch 3/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.4394 - accuracy: 0.8578 - val_loss: 0.9063 - val_accuracy: 0.7311
# Epoch 4/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.2232 - accuracy: 0.9378 - val_loss: 0.8453 - val_accuracy: 0.7467
# Epoch 5/10
# 64/64 [==============================] - 8s 118ms/step - loss: 0.1291 - accuracy: 0.9625 - val_loss: 0.8545 - val_accuracy: 0.7667
# Epoch 6/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0754 - accuracy: 0.9812 - val_loss: 0.8446 - val_accuracy: 0.7533
# Epoch 7/10
# 64/64 [==============================] - 8s 127ms/step - loss: 0.0506 - accuracy: 0.9877 - val_loss: 0.9937 - val_accuracy: 0.7244
# Epoch 8/10
# 64/64 [==============================] - 8s 122ms/step - loss: 0.0342 - accuracy: 0.9904 - val_loss: 1.1741 - val_accuracy: 0.6778
# Epoch 9/10
# 64/64 [==============================] - 8s 125ms/step - loss: 0.0252 - accuracy: 0.9933 - val_loss: 1.2606 - val_accuracy: 0.7044
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83        72
#            1       0.44      0.47      0.46        17
#            2       0.94      0.85      0.89        60
#            3       0.83      0.78      0.80       134
#            4       0.88      0.88      0.88        96
#            5       0.74      0.82      0.77       109
#            6       0.86      1.00      0.92        12
#
#     accuracy                           0.82       500
#    macro avg       0.79      0.80      0.79       500
# weighted avg       0.82      0.82      0.82       500
#
# Accuracy score: 81.600
# F1 Score: 0.817
# Confustion matrix:
# [[ 59   2   1   2   2   6   0]
#  [  2   8   0   1   0   6   0]
#  [  0   3  51   3   0   3   0]
#  [  6   2   1 105   8  12   0]
#  [  0   0   1   5  84   5   1]
#  [  4   3   0  11   1  89   1]
#  [  0   0   0   0   0   0  12]]
# ***********************************************************
# Beginning fold:  10
# WARNING:tensorflow:Layer lstm_53 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 64/64 [==============================] - 8s 124ms/step - loss: 1.7371 - accuracy: 0.2753 - val_loss: 1.8598 - val_accuracy: 0.1333
# Epoch 2/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.9899 - accuracy: 0.6684 - val_loss: 1.1981 - val_accuracy: 0.6000
# Epoch 3/10
# 64/64 [==============================] - 8s 119ms/step - loss: 0.4507 - accuracy: 0.8617 - val_loss: 0.9221 - val_accuracy: 0.7289
# Epoch 4/10
# 64/64 [==============================] - 8s 121ms/step - loss: 0.2330 - accuracy: 0.9378 - val_loss: 0.7850 - val_accuracy: 0.7800
# Epoch 5/10
# 64/64 [==============================] - 8s 127ms/step - loss: 0.1304 - accuracy: 0.9664 - val_loss: 0.8445 - val_accuracy: 0.7422
# Epoch 6/10
# 64/64 [==============================] - 8s 126ms/step - loss: 0.0846 - accuracy: 0.9768 - val_loss: 0.8872 - val_accuracy: 0.7511
# Epoch 7/10
# 64/64 [==============================] - 8s 120ms/step - loss: 0.0576 - accuracy: 0.9849 - val_loss: 1.1945 - val_accuracy: 0.6956
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82        66
#            1       0.61      0.93      0.74        15
#            2       0.85      0.86      0.86        59
#            3       0.87      0.69      0.77       140
#            4       0.91      0.88      0.89       101
#            5       0.71      0.77      0.74       105
#            6       0.82      1.00      0.90        14
#
#     accuracy                           0.81       500
#    macro avg       0.79      0.86      0.82       500
# weighted avg       0.82      0.81      0.81       500
#
# Accuracy score: 80.800
# F1 Score: 0.808
# Confustion matrix:
# [[58  0  0  1  1  6  0]
#  [ 0 14  0  0  0  1  0]
#  [ 2  3 51  0  1  2  0]
#  [10  2  5 97  6 20  0]
#  [ 0  1  0  6 89  4  1]
#  [ 6  3  4  8  1 81  2]
#  [ 0  0  0  0  0  0 14]]
# Mean 0.81 Std 0.02

# %% [markdown]
# # Summary

# %% [markdown]
# I was able to get average of 0.80 F1 score with unprocessed questions. The F1 score is increased by 1% after training the LSTM model with processed and lemmatized questions.
